# %%
import pandas as pd

# %%
pd.read_csv('python Ass.csv')
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
Movies = pd.read_csv('python Ass.csv')

# %%
Movies
# Out:
#      Unnamed: 0 IMBD title ID               Original titlÊ  Release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          Genrë¨ Duration       Country Content Rating  \
# ...

# %%
Movies.shape
# Out:
# (101, 13)

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      101 non-null    int64
#  1   IMBD title ID   100 non-null    object
#  2   Original titlÊ  100 non-null    object
#  3   Release year    100 non-null    object
#  4   Genrë¨          100 non-null    object
#  5   Duration        99 non-null     object
#  6   Country         100 non-null    object
#  7   Content Rating  77 non-null     object
#  8   Director        100 non-null    object
#  9   Unnamed: 8      0 non-null      float64
#  10  Income          100 non-null    object
#  11   Votes          100 non-null    object
#  12  Score           100 non-null    object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 10.4+ KB

# %%
Movies.describe()
# Out:
#        Unnamed: 0  Unnamed: 8
# count  101.000000         0.0
# mean    50.000000         NaN
# std     29.300171         NaN
# min      0.000000         NaN
# 25%     25.000000         NaN
# 50%     50.000000         NaN
# 75%     75.000000         NaN
# max    100.000000         NaN

# %%
Movies.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# Length: 101, dtype: bool

# %% [markdown]
# ###Question
# ... Rename all the column in lower case
# ... Drop the irrelevants column
# ... Exclude  all the null column
# ... Exclude  and replace country column that is abbreviated
# ... Rename the column
# ... convert income column from string to integer
# ... Exclude all the spaces

# %%
Movies.columns = Movies.columns.str.lower()

# %%
Movies
# Out:
#      unnamed: 0 imbd title id               original titlê  release year  \
# 0             0     tt0111161     The Shawshank Redemption    1995-02-10
# 1             1     tt0068646                The Godfather    09 21 1972
# 2             2     tt0468569              The Dark Knight   23 -07-2008
# 3             3     tt0071562       The Godfather: Part II    1975-09-25
# 4             4     tt0110912                 Pulp Fiction    1994-10-28
# ..          ...           ...                          ...           ...
# 96           96     tt0070735                    The Sting    1974-03-21
# 97           97     tt0082096                     Das Boot    1982-03-18
# 98           98     tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99     tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# ...

# %%
Movies.drop(Movies.columns[[0, 9, 11]], axis=1, inplace=True)

# %%
Movies
# Out:
#     imbd title id               original titlê  release year  \
# 0       tt0111161     The Shawshank Redemption    1995-02-10
# 1       tt0068646                The Godfather    09 21 1972
# 2       tt0468569              The Dark Knight   23 -07-2008
# 3       tt0071562       The Godfather: Part II    1975-09-25
# 4       tt0110912                 Pulp Fiction    1994-10-28
# ..            ...                          ...           ...
# 96      tt0070735                    The Sting    1974-03-21
# 97      tt0082096                     Das Boot    1982-03-18
# 98      tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99      tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100     tt0045152          Singin' in the Rain    1953-02-05
#
#                          genrë¨ duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# ...

# %%
Movies.dropna(inplace=True)

# %%
Movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   imbd title id   76 non-null     object
#  1   original titlê  76 non-null     object
#  2   release year    76 non-null     object
#  3   genrë¨          76 non-null     object
#  4   duration        76 non-null     object
#  5   country         76 non-null     object
#  6   content rating  76 non-null     object
#  7   director        76 non-null     object
#  8   income          76 non-null     object
#  9   score           76 non-null     object
# dtypes: object(10)
# memory usage: 6.5+ KB

# %%
Movies.rename(columns = {'imbd title id':'title_id'}, inplace = True)

# %%
Movies.rename(columns = {'original titlê':'original_title'}, inplace = True)

# %%
Movies.rename(columns = {'release year':'release_year'}, inplace = True)

# %%
Movies
# Out:
#      title_id            original_title  release_year  \
# 0   tt0111161  The Shawshank Redemption    1995-02-10
# 1   tt0068646             The Godfather    09 21 1972
# 2   tt0468569           The Dark Knight   23 -07-2008
# 3   tt0071562    The Godfather: Part II    1975-09-25
# 4   tt0110912              Pulp Fiction    1994-10-28
# ..        ...                       ...           ...
# 94  tt2106476                    Jagten    2012-11-22
# 95  tt0056172        Lawrence of Arabia    1963-10-29
# 96  tt0070735                 The Sting    1974-03-21
# 97  tt0082096                  Das Boot    1982-03-18
# 99  tt1832382   Jodaeiye Nader az Simin    2011-10-21
#
#                          genrë¨ duration       country content rating  \
# 0                         Drama      142           USA              R
# 1                  Crime, Drama      175           USA              R
# 2          Action, Crime, Drama      152            US          PG-13
# ...

# %%
Movies.country
# Out:
# 0              USA
# 1              USA
# 2               US
# 3              USA
# 4              USA
#           ...
# 94         Denmark
# 95              UK
# 96             USA
# 97    West Germany
# 99            Iran
# Name: country, Length: 76, dtype: object

# %%
Movies['country'] = Movies['country'].replace(['US','New Zesland','West Germany'],['USA','New Zealand','Germany'])

# %%
Movies
# Out:
#      title_id            original_title  release_year  \
# 0   tt0111161  The Shawshank Redemption    1995-02-10
# 1   tt0068646             The Godfather    09 21 1972
# 2   tt0468569           The Dark Knight   23 -07-2008
# 3   tt0071562    The Godfather: Part II    1975-09-25
# 4   tt0110912              Pulp Fiction    1994-10-28
# ..        ...                       ...           ...
# 94  tt2106476                    Jagten    2012-11-22
# 95  tt0056172        Lawrence of Arabia    1963-10-29
# 96  tt0070735                 The Sting    1974-03-21
# 97  tt0082096                  Das Boot    1982-03-18
# 99  tt1832382   Jodaeiye Nader az Simin    2011-10-21
#
#                          genrë¨ duration  country content rating  \
# 0                         Drama      142      USA              R
# 1                  Crime, Drama      175      USA              R
# 2          Action, Crime, Drama      152      USA          PG-13
# ...

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income score first_genrë¨
# ...

# %%
Movies.release_year
# Out:
# 0       1995-02-10
# 1       09 21 1972
# 2      23 -07-2008
# 3       1975-09-25
# 4       1994-10-28
#           ...
# 94      2012-11-22
# 95      1963-10-29
# 96      1974-03-21
# 97      1982-03-18
# 99      2011-10-21
# Name: release_year, Length: 76, dtype: object

# %%
Movies['release_year'] = pd.to_datetime(Movies['release_year'], errors='coerce')
# Out:
# C:\Users\user pc\AppData\Local\Temp\ipykernel_6120\3625231047.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   Movies['release_year'] = pd.to_datetime(Movies['release_year'], errors='coerce')

# %%
Movies.release_year
# Out:
# 0    1995-02-10
# 1    1972-09-21
# 2    2008-07-23
# 3    1975-09-25
# 4    1994-10-28
#         ...
# 94   2012-11-22
# 95   1963-10-29
# 96   1974-03-21
# 97   1982-03-18
# 99   2011-10-21
# Name: release_year, Length: 76, dtype: datetime64[ns]

# %%
Movies['release_year']=Movies['release_year'].replace(['23 of December of 1966'])

# %%
Movies.release_year
# Out:
# 0    1995-02-10
# 1    1972-09-21
# 2    2008-07-23
# 3    1975-09-25
# 4    1994-10-28
#         ...
# 94   2012-11-22
# 95   1963-10-29
# 96   1974-03-21
# 97   1982-03-18
# 99   2011-10-21
# Name: release_year, Length: 76, dtype: datetime64[ns]

# %%
Movies.drop(Movies.columns[[3]], axis=1, inplace=True)

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income score first_genrë¨
# ...

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income score first_genrë¨
# ...

# %%
Movies['first_genrë¨'] = Movies['first_genrë¨'].replace(['D','c','A'],['Drama','Crime','Action'])

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income score first_genrë¨
# ...

# %%
Movies['first_genrë¨'] = Movies['first_genrë¨'].replace(['C'],['Crime'])

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income score first_genrë¨
# ...

# %%
Movies.income
# Out:
# 0        $ 28815245
# 1       $ 246120974
# 2      $ 1005455211
# 3     $ 4o8,035,783
# 4       $ 222831817
#           ...
# 94       $ 15843274
# 95       $ 45710874
# 96      $ 156000000
# 97       $ 11487676
# 99       $ 22926076
# Name: income, Length: 76, dtype: object

# %%
 Movies['income'].str.split('$', expand=True)
# Out:
#    0              1
# 0          28815245
# 1         246120974
# 2        1005455211
# 3       4o8,035,783
# 4         222831817
# .. ..           ...
# 94         15843274
# 95         45710874
# 96        156000000
# 97         11487676
# 99         22926076
#
# [76 rows x 2 columns]

# %%
Movies['director_income']= Movies['income'].str.split('$', expand=True)[1]

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director         income director_income
# ...

# %%
Movies.drop(Movies.columns[[7]], axis=1, inplace=True)

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director director_income
# 0               R        Frank Darabont        28815245
# ...

# %%
Movies['content rating'] = Movies['content rating'].replace(['Approved', 'Unrated','G','PG','R'], ['Rated','Not Rated','PG-13','PG-13','Rated'])

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director director_income
# 0           Rated        Frank Darabont        28815245
# ...

# %%
def remove_alphabets_and_commas(cell):
    return ''.join(char for char in cell if char.isdigit())

Movies.director_income = Movies.director_income.apply(remove_alphabets_and_commas)

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director director_income
# 0           Rated        Frank Darabont        28815245
# ...

# %%
Movies.director_income =Movies.director_income.astype(int)

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director  director_income
# 0           Rated        Frank Darabont         28815245
# ...

# %%
Movies.director_income = Movies.director_income.apply(lambda x: '${:,.0f}'.format(x))

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director director_income
# 0           Rated        Frank Darabont     $28,815,245
# ...

# %%
Movies
# Out:
#      title_id            original_title release_year duration  country  \
# 0   tt0111161  The Shawshank Redemption   1995-02-10      142      USA
# 1   tt0068646             The Godfather   1972-09-21      175      USA
# 2   tt0468569           The Dark Knight   2008-07-23      152      USA
# 3   tt0071562    The Godfather: Part II   1975-09-25      220      USA
# 4   tt0110912              Pulp Fiction   1994-10-28               USA
# ..        ...                       ...          ...      ...      ...
# 94  tt2106476                    Jagten   2012-11-22      115  Denmark
# 95  tt0056172        Lawrence of Arabia   1963-10-29      228       UK
# 96  tt0070735                 The Sting   1974-03-21      129      USA
# 97  tt0082096                  Das Boot   1982-03-18      149  Germany
# 99  tt1832382   Jodaeiye Nader az Simin   2011-10-21      123     Iran
#
#    content rating              director director_income
# 0           Rated        Frank Darabont     $28,815,245
# ...
